# %% [markdown]
# **INSTALL LIBRARIES**

# %%
# !pip install -U sentence-transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 KB 1.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 57.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 34.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.8/199.8 KB 10.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 73.8 MB/s eta 0:00:00
# ...
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125942 sha256=4dd07d46ba1a836d8bf1d2ac4ec7fc412a287b6c8cbe3c19cc9a45840b7f9104
#   Stored in directory: /root/.cache/pip/wheels/71/67/06/162a3760c40d74dd40bc855d527008d26341c2b0ecf3e8e11f
# Successfully built sentence-transformers
# ...

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from transformers import AutoModelForQuestionAnswering, AutoTokenizer, pipeline
model_name = "deepset/roberta-base-squad2"
nlp = pipeline('question-answering', model=model_name, tokenizer=model_name)

# %%
# !pip install newscatcherapi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.8/293.8 KB 21.5 MB/s eta 0:00:00
# ...

# %%
# !pip install gnews
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.4/188.4 KB 25.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 KB 7.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 516.3/516.3 KB 46.4 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.8/115.8 KB 12.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.1/81.1 KB 10.3 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1270 sha256=9b00e8b7e08a7deebc43886022a52d37ef3a8c898eb2fc558f0df1d3e9827094
#   Stored in directory: /root/.cache/pip/wheels/73/2b/cb/099980278a0c9a3e57ff1a89875ec07bfa0b6fcbebb9a8cad3
# ...

# %%
from newscatcherapi import NewsCatcherApiClient
newscatcherapi = NewsCatcherApiClient(x_api_key='FrFdPl9T9xPMrqpuJtYcHMzs0eU7E4XsxjWzXQ1wZwI')

# %%
from gnews import GNews
google_news = GNews()

# %%
medical_catcher_api = newscatcherapi.get_search(q='medical research', lang='en', page_size=100)
medical_google_api = google_news.get_news('medical research')

# %% [markdown]
# **EXTRACT MEDICAL RESEARCH INFORMATION**

# %%
sentence = []
link = []
dates = []
for vals in medical_catcher_api['articles']:
  try:
    article = Article(vals['link'])
    article.download()
    article.parse()
    sentence.append(article.title+". "+article.text)
    link.append(vals['link'])
    dates.append(vals['published_date'])
  except:
    pass
for vals in medical_google_api:
  try:
    article = google_news.get_full_article(vals['url'])
    sentence.append(article.title+". "+article.text)
    link.append(vals['url'])
    dates.append(vals['published date'])
  except:
    pass

medical_df = pd.DataFrame({"URL":link,"Date":dates,"Text":sentence})
# Out:
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ...
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ...

# %%
import pandas as pd
medical_df = pd.DataFrame({"URL":link,"Date":dates,"Text":sentence})

# %%
import pickle
with open("Medic.pkl","wb") as f:
  pickle.dump((medical_df),f)

# %%
embeddings_medical = model.encode(medical_df['Text'].tolist())

statement = "new medical research"
statement_embedding = model.encode(statement)
EMBEDDING_SIZE = embeddings_medical.shape[1]
scores1 = []
for vals in embeddings_medical:
  scores1.append(cosine_similarity(vals.reshape(-1,EMBEDDING_SIZE),statement_embedding.reshape(-1,EMBEDDING_SIZE))[0][0])

medical_df['Similarity'] = scores1
medical_df = medical_df.sort_values(by=['Similarity'], ascending=False).reset_index(drop=True)
# Out:
# ...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
research = []
for i in range(10):
  QA_input = {
      'question': 'What is the research about?',
      'context': medical_df['Text'][i]
  }
  res = nlp(QA_input)
  research.append(res['answer'])

# %%
research_df = pd.DataFrame({"DATE":medical_df['Date'].tolist()[:10], "RESEARCH TYPE":research,"ARTICLE":medical_df["URL"].tolist()[:10]})
research_df
# Out:
#                             DATE  \
# 0  Tue, 28 Mar 2023 20:48:11 GMT
# 1  Tue, 28 Mar 2023 12:24:00 GMT
# 2  Mon, 20 Mar 2023 07:00:00 GMT
# 3  Sat, 01 Apr 2023 23:18:36 GMT
# 4  Fri, 24 Mar 2023 03:58:47 GMT
# 5  Mon, 27 Mar 2023 07:05:46 GMT
# 6  Fri, 31 Mar 2023 08:07:25 GMT
# 7  Mon, 27 Mar 2023 16:14:23 GMT
# 8  Tue, 14 Mar 2023 07:00:00 GMT
# 9  Fri, 24 Mar 2023 06:11:11 GMT
#
#                                        RESEARCH TYPE  \
# 0  helps professionals understand and improve dis...
# 1  Medical Research Ethics: Challenges in the 21s...
# 2  discovery and development of treatments for ma...
# 3  aims to tackle hundreds of different diseases ...
# 4  \n\nresearch organisations\n\nother health and...
# 5  eliminate disease and improve the health of ev...
# 6                         improve healthcare for all
# 7                                    Paweł Łaniewski
# 8           investigations of younger-onset dementia
# 9                  \n\na pre-MRFF RAO webinar survey
#
# ...
